# %%
# %matplotlib inline

# %%
from pylab import *
import pandas as pd

# %%
fname = "/home/ronen/Dropbox/master/alab/R01C100_01_ovend.res"
# !cat /home/ronen/Dropbox/master/alab/R01C100_01_ovend.res
# Out:
# Vol [cm3]	1.000E+0	Mass[g]	1.000E+0
# time[s]	Tb[K]before	field[T]	average Z-Moment	Ta[K]	Tb[K]after	 STD	Z-Scan1  	Z-Scan2  	Z-Scan3
# 3.4348701E+9	8.7873001E+0	1.9999999E-4	-3.1686619E-7	6.0251999E+0	8.5840998E+0	1.7734172E-10	-3.1664621E-7	-3.1687188E-7	-3.1708050E-7
# 3.4348702E+9	8.3708000E+0	1.9999999E-4	-3.1614120E-7	5.9130001E+0	8.1694002E+0	5.1179233E-10	-3.1671749E-7	-3.1623229E-7	-3.1547383E-7
# 3.4348703E+9	8.1145000E+0	1.9999999E-4	-3.1687638E-7	5.8432999E+0	7.9176998E+0	2.1512930E-10	-3.1717073E-7	-3.1666258E-7	-3.1679584E-7
# 3.4348703E+9	7.8748002E+0	1.9999999E-4	-3.1643737E-7	6.2381001E+0	7.8608999E+0	2.8358753E-10	-3.1632778E-7	-3.1682627E-7	-3.1615807E-7
# 3.4348703E+9	7.9014001E+0	1.9999999E-4	-3.1626842E-7	6.6219001E+0	8.1232004E+0	2.9304373E-10	-3.1665859E-7	-3.1595235E-7	-3.1619433E-7
# 3.4348704E+9	8.1920004E+0	1.9999999E-4	-3.1660625E-7	7.0114002E+0	8.4292002E+0	4.8899613E-10	-3.1592087E-7	-3.1702871E-7	-3.1686918E-7
# ...

# %%
f = loadtxt(fname, skiprows=2).T

# %%
from __future__ import unicode_literals

figure(figsize=(5,5))

matplotlib.rc('font', family='David CLM')


plot(f[1], f[3],".-")
mpl.rcParams['ytick.labelsize'] = 20 

ylabel(bidialg.get_display(u"(תגובה מגנטית (יחידות שרירותיות"), fontsize=20)
xlabel(bidialg.get_display(u"טמפרטורה [K]"), fontsize=20)
frame1 = gca()
frame1.axes.get_yaxis().set_ticks([])

savefig("../pics/calabalcu_phase.png")

# %%
from bidi import algorithm as bidialg
import matplotlib.pyplot as plt

plt.text(0.5, 0.5, text , name = 'David CLM')
xlabel(text, )
plt.show()

# %%
pwd
# Out:
# u'/home/ronen/gits/superconductors_talk_for_icon.bak/notebook'
